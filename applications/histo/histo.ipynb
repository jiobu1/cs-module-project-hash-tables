# %%
# Import libraries
import re
import matplotlib.pyplot as plt

# %%
# Open file
file = open("/Users/jisha/Desktop/Lambda_Course_Work/Coursework/Work/2. Computer Science/5. Hash Tables /cs-module-project-hash-tables/applications/histo/robin.txt", "r+")

# %%
text = file.read()

# %%
# lowercase text and remove extraneous characters
text = text.lower()
words = re.split(r"[^\w']+",text)

# %%
print(f"Number of words in text file:  {len(words)}")
# Out:
# Number of words in text file:  928

# %%
d = dict()

# %%
for word in words:
    if word in d:
        d[word] +=1
    else:
        d[word] = 1

# %%
print(d)
# Out:
# {'in': 11, 'merry': 6, 'england': 1, 'the': 48, 'time': 3, 'of': 35, 'old': 1, 'when': 6, 'good': 10, 'king': 1, 'henry': 1, 'second': 1, 'ruled': 1, 'land': 1, 'there': 4, 'lived': 2, 'within': 2, 'green': 7, 'glades': 1, 'sherwood': 3, 'forest': 3, 'near': 1, 'nottingham': 5, 'town': 3, 'a': 24, 'famous': 1, 'outlaw': 1, 'whose': 1, 'name': 1, 'was': 5, 'robin': 13, 'hood': 2, 'no': 5, 'archer': 1, 'ever': 3, 'that': 12, 'could': 1, 'speed': 1, 'gray': 2, 'goose': 2, 'shaft': 2, 'with': 17, 'such': 3, 'skill': 1, 'and': 36, 'cunning': 1, 'as': 9, 'his': 12, 'nor': 2, 'were': 6, 'yeomen': 2, 'sevenscore': 1, 'men': 3, 'roamed': 1, 'him': 1, 'through': 2, 'greenwood': 2, 'shades': 1, 'right': 3, 'merrily': 1, 'they': 6, 'dwelled': 2, 'depths': 1, 'suffering': 1, 'neither': 1, 'care': 1, 'want': 1, 'but': 2, 'passing': 1, 'games': 1, 'archery': 1, 'or': 3, 'bouts': 1, 'cudgel': 1, 'play': 1, 'living': 1, 'upon': 7, "king's": 1, 'venison': 1, 'washed': 1, 'down': 3, 'draughts': 1, 'ale': 6, 'october': 2, 'brewing': 2, 'not': 1, 'only': 2, 'himself': 2, 'all': 6, 'band': 1, 'outlaws': 1, 'apart': 1, 'from': 3, 'other': 3, 'yet': 3, 'beloved': 1, 'by': 4, 'country': 1, 'people': 1, 'round': 1, 'about': 2, 'for': 7, 'one': 6, 'came': 3, 'to': 16, 'jolly': 1, 'help': 2, 'need': 1, 'went': 1, 'away': 1, 'again': 1, 'an': 2, 'empty': 1, 'fist': 1, 'now': 4, 'i': 10, 'will': 4, 'tell': 1, 'how': 2, 'it': 4, 'fell': 1, 'afoul': 1, 'law': 1, 'youth': 1, 'eighteen': 1, 'stout': 4, 'sinew': 1, 'bold': 2, 'heart': 1, 'sheriff': 2, 'proclaimed': 2, 'shooting': 2, 'match': 2, 'offered': 2, 'prize': 2, 'butt': 3, 'whosoever': 1, 'should': 1, 'shoot': 2, 'best': 4, 'nottinghamshire': 2, 'quoth': 3, 'go': 2, 'too': 1, 'fain': 1, 'would': 1, 'draw': 2, 'string': 2, 'bright': 4, 'eyes': 2, 'my': 2, 'lass': 2, 'so': 1, 'up': 2, 'he': 12, 'got': 1, 'took': 2, 'yew': 2, 'bow': 6, 'score': 1, 'more': 2, 'broad': 2, 'clothyard': 2, 'arrows': 2, 'started': 1, 'off': 1, 'locksley': 1, 'at': 10, 'dawn': 2, 'day': 2, 'maytime': 1, 'hedgerows': 1, 'are': 4, 'flowers': 1, 'bedeck': 1, 'meadows': 1, 'daisies': 1, 'pied': 1, 'yellow': 1, 'cuckoo': 2, 'buds': 2, 'fair': 4, 'primroses': 1, 'along': 4, 'briery': 1, 'hedges': 1, 'apple': 1, 'blossom': 1, 'sweet': 3, 'birds': 2, 'sing': 1, 'lark': 1, 'throstle': 1, 'cock': 1, 'lads': 1, 'lasses': 1, 'look': 1, 'each': 3, 'thoughts': 2, 'busy': 1, 'housewives': 1, 'spread': 1, 'their': 1, 'linen': 1, 'bleach': 1, 'grass': 1, 'walked': 2, 'its': 1, 'paths': 1, 'rustling': 1, 'leaves': 1, 'amid': 1, 'which': 5, 'little': 2, 'sang': 1, 'might': 1, 'main': 1, 'blithely': 1, 'whistled': 1, 'trudged': 1, 'thinking': 1, 'maid': 1, 'marian': 1, 'her': 1, 'times': 1, "youth's": 1, 'wont': 1, 'turn': 1, 'pleasantly': 1, 'loves': 1, 'thus': 1, 'brisk': 1, 'step': 1, 'whistle': 1, 'suddenly': 1, 'some': 1, 'foresters': 1, 'seated': 2, 'beneath': 2, 'great': 2, 'oak': 1, 'tree': 2, 'fifteen': 1, 'making': 1, 'themselves': 1, 'feasting': 1, 'drinking': 1, 'sat': 1, 'around': 1, 'huge': 1, 'pasty': 1, 'man': 2, 'helped': 1, 'thrusting': 1, 'hands': 1, 'into': 1, 'pie': 1, 'washing': 1, 'ate': 1, 'horns': 1, 'drew': 2, 'foaming': 1, 'barrel': 1, 'stood': 1, 'nigh': 2, 'clad': 1, 'lincoln': 1, 'fine': 2, 'show': 1, 'made': 1, 'sward': 1, 'spreading': 1, 'then': 5, 'them': 2, 'mouth': 1, 'full': 1, 'called': 1, 'out': 1, 'hulloa': 1, 'where': 1, 'goest': 1, 'thou': 7, 'lad': 2, 'thy': 5, 'penny': 1, 'farthing': 1, 'shafts': 1, 'grew': 2, 'angry': 1, 'stripling': 1, 'likes': 1, 'be': 2, 'taunted': 1, 'years': 1, 'eke': 1, 'mine': 2, 'shine': 1, 'moreover': 1, 'same': 1, 'has': 2, 'been': 2, 'our': 4, 'who': 3, 'held': 1, 'horn': 1, 'hand': 2, 'said': 3, 'ho': 1, 'listen': 1, 'why': 1, 'boy': 1, "mother's": 1, 'milk': 2, 'is': 2, 'scarce': 2, 'dry': 1, 'lips': 1, 'pratest': 1, 'standing': 1, 'butts': 1, 'art': 1, 'able': 1, 'two': 1, 'stone': 1, "i'll": 2, 'hold': 2, 'you': 2, 'twenty': 3, 'marks': 3, 'hit': 1, 'clout': 1, 'threescore' ...

# %%
len(d.keys())
# Out:
# 411

# %%
d = {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}

# %%
plt.figure(figsize=(20,70))
plt.barh(list(d.keys()), d.values(), height=0.5, color='g' )
plt.ylim(-1, 411)
plt.show()
